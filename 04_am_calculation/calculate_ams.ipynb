# %%
from am_calculator import AMCalculator
from src.config import *

# %%
# Remove old AM Columns to recalculate them.
"""
import pandas as pd
df = pd.read_csv(DATASET_PATH, dtype={"clip_id": str})
df = df.drop(columns=AM_COLUMN_NAMES)
df.to_csv(DATASET_PATH, index=False)
"""
# Out:
# '\nimport pandas as pd\ndf = pd.read_csv(DATASET_PATH, dtype={"clip_id": str})\ndf = df.drop(columns=AM_COLUMN_NAMES)\ndf.to_csv(DATASET_PATH, index=False)\n'

# %%
DATASET_PATH = "/run/media/chr1s/chr1sdrive2/acoustic-to-anthropometric/datasets/train_10000_lms.feather"
new_path = DATASET_PATH.replace("lms.feather", "ams.feather")

# %%
am_calculator = AMCalculator(DATASET_PATH)

# %%
am_calculator.calculate_ams(n_jobs=10, new_path=new_path)
# Out:
# Calculating AMs:  64%|██████▍   | 6410/10000 [00:01<00:00, 7899.02it/s]
# Error calculating AMs for 4426:
# array must not contain infs or NaNs
# Calculating AMs: 100%|██████████| 10000/10000 [00:02<00:00, 4626.12it/s]

# %%
import pandas as pd
df = pd.read_feather(new_path)
df.head()
# Out:
#   speaker_id  face_id gender  split     video_id clip_id  batch  \
# 0    id00012  n000012      m  train  _raOc3-IRsw   00110      1
# 1    id00012  n000012      m  train  _raOc3-IRsw   00114      1
# 2    id00012  n000012      m  train  _raOc3-IRsw   00112      1
# 3    id00012  n000012      m  train  _raOc3-IRsw   00111      1
# 4    id00012  n000012      m  train  _raOc3-IRsw   00113      1
#
#    audspec_lengthL1norm_sma_range  audspec_lengthL1norm_sma_maxPos  \
# 0                        1.564974                         0.003774
# 1                        1.748977                         0.521542
# 2                        1.968397                         0.009217
# 3                        1.596150                         0.401869
# 4                        2.156229                         0.441805
#
#    audspec_lengthL1norm_sma_minPos  ...  distance_16_08  distance_33_08  \
# 0                         0.273585  ...        1.463315        0.741822
# 1                         0.575964  ...        1.488841        0.788406
# 2                         0.914747  ...        1.485398        0.779928
# 3                         0.953271  ...        1.464441        0.800565
# 4                         0.814727  ...        1.457218        0.776877
#
#    distance_00_27  distance_16_27  distance_04_08  distance_12_08  \
# 0        1.143794        1.130462        0.873205        0.864059
# 1        1.154262        1.131495        0.863373        0.861859
# 2        1.149290        1.128816        0.871123        0.870130
# 3        1.125874        1.106447        0.852040        0.850530
# 4        1.146347        1.127089        0.860801        0.856177
#
#    distance_60_64  distance_51_62  distance_57_66  distance_31_35
# 0        0.490037        0.067177        0.064329        0.265229
# 1        0.467520        0.072253        0.071403        0.265667
# 2        0.491795        0.069688        0.070287        0.273485
# 3        0.455240        0.071137        0.071140        0.256185
# 4        0.517907        0.068809        0.069081        0.275308
#
# [5 rows x 6600 columns]
