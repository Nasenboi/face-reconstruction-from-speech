# %%
import os
from data_preparation import DataPreparation
from src.paths import *

# %%
datasets = os.listdir(DATASET_PATH)
batch_df = os.path.join(DATASET_PATH, datasets[0])
datasets, batch_df
# Out:
# (['train_001_250037.csv',
#   'train_002_250066.csv',
#   'train_003_250037.csv',
#   'train_004_250125.csv',
#   'train_005_91744.csv'],
#  '/run/media/chr1s/chr1sdrive2/acoustic-to-anthropometric/datasets/train_001_250037.csv')

# %%
dataset_preparation = DataPreparation(batch_df)

# %%
dataset_preparation.extract_frames()

# %%
dataset_preparation.calculate_audio_features()
