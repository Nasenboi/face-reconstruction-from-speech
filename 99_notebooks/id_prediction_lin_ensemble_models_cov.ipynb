# %%
# Basic imports
import os
import sys
sys.path.append("..")
from src.config import *
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Preset Variables if needed:
RANDOM_STATE = 1
np.random.seed(RANDOM_STATE)

# %%
df_path = os.path.join(CONFIG["paths"]["datasets"], "train_001-003_cov.feather")
train_df = pd.read_feather(df_path)
#df = df.set_index("dataset_id")
#train_df["gender_m"] = (train_df["gender"] == "m") * 1
train_df = train_df.dropna()
train_df.head()
# Out:
#   speaker_id  face_id gender  split     video_id clip_id  batch     id_00  \
# 0    id00012  n000012      m  train  _raOc3-IRsw   00110      1 -0.534247
# 1    id00012  n000012      m  train  _raOc3-IRsw   00110      1 -1.232415
# 2    id00012  n000012      m  train  _raOc3-IRsw   00110      1 -1.198748
# 3    id00012  n000012      m  train  _raOc3-IRsw   00114      1 -0.395865
# 4    id00012  n000012      m  train  _raOc3-IRsw   00114      1 -1.521436
#
#       id_01     id_02  ...    emb_182    emb_183   emb_184    emb_185  \
# 0  0.446597 -0.702078  ... -69.511604 -20.780977  5.991487  30.202063
# 1  0.044864 -0.898896  ... -69.511604 -20.780977  5.991487  30.202063
# 2  0.023967 -0.991005  ... -69.511604 -20.780977  5.991487  30.202063
# 3  0.226113 -1.174716  ... -26.287624  -4.299731  3.730465  24.861532
# 4 -0.030570 -1.077428  ... -26.287624  -4.299731  3.730465  24.861532
#
#     emb_186    emb_187    emb_188    emb_189    emb_190    emb_191
# ...

# %%
df_path = os.path.join(CONFIG["paths"]["datasets"], "val_004_cov.feather")
val_df = pd.read_feather(df_path)
#df = df.set_index("dataset_id")
#val_df["gender_m"] = (val_df["gender"] == "m") * 1
val_df = val_df.dropna()
val_df.head()
# Out:
#   speaker_id  face_id gender  split     video_id clip_id  batch     id_00  \
# 0    id06431  n006430      f  train  k3VkS_pwOy4   00029      4 -2.126668
# 1    id06431  n006430      f  train  k3VkS_pwOy4   00030      4 -1.816971
# 2    id06431  n006430      f  train  k3VkS_pwOy4   00028      4 -1.948257
# 3    id06431  n006430      f  train  T31jfRa4Ywo   00023      4 -1.732887
# 4    id06431  n006430      f  train  T31jfRa4Ywo   00024      4 -1.567235
#
#       id_01     id_02  ...    emb_182    emb_183    emb_184    emb_185  \
# 0  0.347746 -0.497481  ...  27.276220   3.878556  15.254556 -11.144983
# 1  0.191004 -0.205672  ...   8.716928 -15.893596  38.441517 -13.844922
# 2  0.351657 -0.509323  ...  37.173748  -6.960853   1.248851  -9.474826
# 3  0.006009 -1.059875  ...  23.910795 -12.609481  -4.637720 -16.041262
# 4 -0.149104 -1.065036  ...  11.489490   3.970654  11.203156 -25.017487
#
#      emb_186    emb_187    emb_188    emb_189    emb_190    emb_191
# ...

# %%
df_path = os.path.join(CONFIG["paths"]["datasets"], "test_005_cov.feather")
test_df = pd.read_feather(df_path)
#df = df.set_index("dataset_id")
#test_df["gender_m"] = (test_df["gender"] == "m") * 1
test_df = test_df.dropna()
test_df.head()
# Out:
#   speaker_id  face_id gender  split     video_id clip_id  batch     id_00  \
# 0    id08520  n008519      m  train  DyD-InvSns0   00026      5 -0.569495
# 1    id08520  n008519      m  train  DyD-InvSns0   00025      5 -0.969477
# 2    id08520  n008519      m  train  71FRFxu4L4Y   00009      5 -0.893348
# 3    id08520  n008519      m  train  71FRFxu4L4Y   00013      5 -0.808268
# 4    id08520  n008519      m  train  71FRFxu4L4Y   00014      5 -0.719186
#
#       id_01     id_02  ...    emb_182    emb_183    emb_184   emb_185  \
# 0 -0.560662 -1.253153  ...  -4.934443  -9.456514 -10.861115 -7.752863
# 1 -0.872817 -1.203463  ...   9.073496   6.501635 -18.162807 -8.158441
# 2 -0.867205 -1.439932  ...  -5.560208  -7.290378  -4.824924 -9.730695
# 3 -0.842630 -1.325965  ...  -8.898027  -5.530489  -6.049358 -4.447079
# 4 -0.582695 -1.127047  ...  12.186457 -19.709862  -1.411152 -6.789989
#
#      emb_186    emb_187    emb_188    emb_189    emb_190    emb_191
# ...

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 56898 entries, 0 to 56929
# Columns: 279 entries, speaker_id to emb_191
# dtypes: float32(192), float64(80), int64(1), object(6)
# memory usage: 79.9+ MB

# %%
ID_COLUMN_NAMES = [c for c in train_df.columns if "id_" in c]
info_columns = [
    "speaker_id",
    "face_id",
    "gender",
    "split",
    "video_id",
    "clip_id",
    "batch"
]

# %%
corr = train_df.drop(columns=info_columns).corr()
corr = corr[ID_COLUMN_NAMES[10:20]].T.drop(columns=ID_COLUMN_NAMES)
top_10_corr = list(corr.abs().sum().nlargest(10).index)
corr = corr[top_10_corr]
sns.heatmap(corr, annot=True, fmt=".2f")
plt.title("Top 10 Audio Feature to ID Correlations")
plt.show()

# %%
y_column_names = ID_COLUMN_NAMES
y_test, y_train = test_df[y_column_names], train_df[y_column_names]
X_test, X_train = test_df.drop(columns=y_column_names+info_columns), train_df.drop(columns=y_column_names+info_columns)

# %%
ID_COLUMN_NAME = "id_00"
y_test, y_train = y_test[ID_COLUMN_NAME], y_train[ID_COLUMN_NAME]

# %%
"""
from sklearn.preprocessing import StandardScaler

X_scaler = StandardScaler()
X_train = pd.DataFrame(X_scaler.fit_transform(X_train.values), columns=X_train.columns)
X_test = pd.DataFrame(X_scaler.transform(X_test.values), columns=X_test.columns)

y_scaler = StandardScaler()
y_train = pd.DataFrame(y_scaler.fit_transform(pd.DataFrame(y_train)), columns=[AM_COLUMN_NAME]).values
y_test = pd.DataFrame(y_scaler.transform(pd.DataFrame(y_test)), columns=[AM_COLUMN_NAME]).values
"""
# Out:
# '\nfrom sklearn.preprocessing import StandardScaler\n\nX_scaler = StandardScaler()\nX_train = pd.DataFrame(X_scaler.fit_transform(X_train.values), columns=X_train.columns)\nX_test = pd.DataFrame(X_scaler.transform(X_test.values), columns=X_test.columns)\n\ny_scaler = StandardScaler()\ny_train = pd.DataFrame(y_scaler.fit_transform(pd.DataFrame(y_train)), columns=[AM_COLUMN_NAME]).values\ny_test = pd.DataFrame(y_scaler.transform(pd.DataFrame(y_test)), columns=[AM_COLUMN_NAME]).values\n'

# %%
import numpy as np
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

class AVG_MODEL:
    def __init__(self):
        self.mean_value = None
    
    def fit(self, X, y):
        self.mean_value = np.mean(y)
        return self
    
    def predict(self, X):
        if self.mean_value is None:
            raise ValueError("Model must be fitted before prediction")
        return np.full(X.shape[0], self.mean_value)

def evaluate_model(m_name: str, m, x = X_test, y = y_test):
    """Evaluate model performance on test data"""
    pred = m.predict(x)
    print(f"Evaluation for Model {m_name}:")
    print(f"Mean Absolute Error: {mean_absolute_error(y, pred):.4f}")
    print(f"Mean Squared Error : {mean_squared_error(y, pred):.4f}")
    print(f"R2 Score           : {r2_score(y, pred):.4f}")

# %%
avg_model = AVG_MODEL().fit(X_train, y_train)
evaluate_model("AVG_Model", avg_model)
# Out:
# Evaluation for Model AVG_Model:
# Mean Absolute Error: 0.4773
# Mean Squared Error : 0.3340
# R2 Score           : -0.0194

# %%
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import GridSearchCV

"""
param_grid = {
    "n_estimators": [100, 500, 1000],
    "max_depth": [3, 5, 7],
    "learning_rate": [0.1, 0.01, 0.001]
}
"""
param_grid = {
    "n_estimators": [2000],
    "max_depth": [5],
    "learning_rate": [0.01]
}

models = GridSearchCV(
    estimator=GradientBoostingRegressor(random_state=RANDOM_STATE),
    param_grid=param_grid,
    n_jobs=10,
    scoring="neg_mean_absolute_error",
)
models.fit(X_train, y_train)
model = models.best_estimator_
models.best_params_
# Out:
# {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 2000}

# %%
evaluate_model("GradientBoostingRegressor", model)
# Out:
# Evaluation for Model GradientBoostingRegressor:
# Mean Absolute Error: 0.3851
# Mean Squared Error : 0.2302
# R2 Score           : 0.2974

# %%
import shap
explainer = shap.TreeExplainer(model)
shap_values = explainer.shap_values(X_test)

shap.summary_plot(shap_values, X_test, feature_names=X_test.columns)
# Out:
# /tmp/ipykernel_1733067/2590252497.py:5: FutureWarning: The NumPy global RNG was seeded by calling `np.random.seed`. In a future version this function will no longer use the global RNG. Pass `rng` explicitly to opt-in to the new behaviour and silence this warning.
#   shap.summary_plot(shap_values, X_test, feature_names=X_test.columns)

# %%
# y_train_pred = ((model.predict(X_train) + 1 ) * 2) -1 
y_train_pred = model.predict(X_train)

plt.figure(figsize=(10, 6))
plt.scatter(y_train, y_train_pred, alpha=0.1, c=(train_df["gender"] == "m") * 1, 
                     cmap="viridis", label="gender")
plt.xlabel("True Values (y_train)")
plt.ylabel("Predicted Values (y_train_pred)")
plt.title("True vs Predicted Values")

# Add a diagonal line for perfect predictions
min_val = min(y_train.min(), y_train_pred.min())
max_val = max(y_train.max(), y_train_pred.max())
plt.plot([min_val, max_val], [min_val, max_val], "r--", linewidth=2, label="Perfect Prediction")

plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %%
#y_test_pred = ((model.predict(X_test) + 1) * 3 ) -1
y_test_pred = model.predict(X_test)

plt.figure(figsize=(10, 6))

# Create scatter plot colored by gender_m
scatter = plt.scatter(y_test, y_test_pred, c=(test_df["gender"] == "m") * 1, alpha=0.1, 
                     cmap="viridis", label="gender")

plt.xlabel("True Values (y_test)")
plt.ylabel("Predicted Values (y_test_pred)")
plt.title("True vs Predicted Values (Colored by Gender)")

# Add a diagonal line for perfect predictions
min_val = min(y_test.min(), y_test_pred.min())
max_val = max(y_test.max(), y_test_pred.max())
plt.plot([min_val, max_val], [min_val, max_val], "r--", linewidth=2, label="Perfect Prediction")

# Add colorbar to show gender mapping
cbar = plt.colorbar(scatter)
cbar.set_label("Gender (0=Female, 1=Male)")

plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()
