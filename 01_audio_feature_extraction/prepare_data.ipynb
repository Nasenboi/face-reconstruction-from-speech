# %%
"""
import os 
import pandas as pd

num_files = 10_000

old_path = ""
df = pd.read_feather(old_path, dtype={"clip_id": str})
df = df.head(num_files)
df.to_csv(DATASET_PATH, index=False)
"""

# %%
"""
import os
import pandas as pd

ds_path = "/run/media/chr1s/chr1sdrive2/acoustic-to-anthropometric/datasets"
dsets = os.listdir(ds_path)

for ds in dsets:
    ds_file = os.path.join(ds_path, ds)
    output_file = ds_file.replace(".csv", ".feather")
    df = pd.read_csv(ds_file, dtype={"clip_id": str})
    df.to_feather(output_file, compression="zstd", compression_level=3)
"""

# %%
from data_preparation import DataPreparation
from src.config import *

# %%
new_path = DATASET_PATH.replace(".feather", "_audio_features.feather")

# %%
dataset_preparation = DataPreparation()

# %%
dataset_preparation.calculate_audio_features(new_path=new_path, n_jobs=10, timeout=900)
# Out:
# Calculating Audio Features: 100%|██████████| 10000/10000 [04:02<00:00, 41.18it/s]
# Dropping Na:
# Concatinating Dicts
# Resetting Index
# Saving to Feather...

# %%
import pandas as pd

df = pd.read_feather(new_path)

# %%
df.head()
# Out:
#   speaker_id  face_id gender  split     video_id clip_id  batch  mel_000_000  \
# 0    id00012  n000012      m  train  _raOc3-IRsw   00110      1     0.008469
# 1    id00012  n000012      m  train  _raOc3-IRsw   00114      1     0.002859
# 2    id00012  n000012      m  train  _raOc3-IRsw   00112      1     0.003049
# 3    id00012  n000012      m  train  _raOc3-IRsw   00111      1     0.020360
# 4    id00012  n000012      m  train  _raOc3-IRsw   00113      1     0.006241
#
#    mel_001_000  mel_002_000  ...  mel_118_127  mel_119_127  mel_120_127  \
# 0     0.003709     0.002483  ...     0.000034     0.000019     0.000006
# 1     0.001468     0.001828  ...     0.000058     0.000054     0.000030
# 2     0.002912     0.003164  ...     0.000021     0.000040     0.000033
# 3     0.008218     0.004215  ...     0.000005     0.000014     0.000055
# 4     0.001602     0.000408  ...     0.000172     0.000117     0.000033
#
#    mel_121_127  mel_122_127  mel_123_127  mel_124_127   mel_125_127  \
# 0     0.000002     0.000003     0.000015     0.000057  9.200822e-05
# 1     0.000026     0.000010     0.000004     0.000002  9.672775e-07
# 2     0.000010     0.000017     0.000017     0.000017  6.026548e-06
# 3     0.000041     0.000016     0.000017     0.000013  1.225858e-05
# 4     0.000022     0.000025     0.000023     0.000006  5.286750e-06
#
#     mel_126_127  mel_127_127
# 0  7.834550e-05     0.000025
# 1  5.523870e-07     0.000003
# 2  8.420480e-06     0.000008
# 3  2.516619e-05     0.000013
# 4  9.543614e-06     0.000008
#
# [5 rows x 16391 columns]

# %%
len(df), len(df.dropna())

# %% [markdown]
# # Size and speed:
# 10_000 files, 6373 audio features:
#
# csv size: 640 MiB
# Loading time: 7s
#
# feather size: 206 MiB
# Loading time: 0.3s
